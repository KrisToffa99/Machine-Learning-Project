# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('Hepatits.csv')

# %%
data.head()
# Out:
#    class  age  sex  steroid  antivirals  fatigue  malaise  anorexia  \
# 0      2   30    2        1           2        2        2         2
# 1      2   50    1        1           2        1        2         2
# 2      2   78    1        2           2        1        2         2
# 3      2   34    1        2           2        2        2         2
# 4      2   34    1        2           2        2        2         2
#
#    liver_big  liver_firm  spleen_palable  spiders  ascites  varices  \
# 0          1           2               2        2        2        2
# 1          1           2               2        2        2        2
# 2          2           2               2        2        2        2
# 3          2           2               2        2        2        2
# 4          2           2               2        2        2        2
#
#    bilirubin  alk_phosphate  sgot  albumin  protime  histology
# 0        1.0             85    18      4.0       61          1
# ...

# %%
data['class'].replace([2,1],[1,0], inplace=True)
data['class'].value_counts()
data.head()
# Out:
#    class  age  sex  steroid  antivirals  fatigue  malaise  anorexia  \
# 0      1   30    2        1           2        2        2         2
# 1      1   50    1        1           2        1        2         2
# 2      1   78    1        2           2        1        2         2
# 3      1   34    1        2           2        2        2         2
# 4      1   34    1        2           2        2        2         2
#
#    liver_big  liver_firm  spleen_palable  spiders  ascites  varices  \
# 0          1           2               2        2        2        2
# 1          1           2               2        2        2        2
# 2          2           2               2        2        2        2
# 3          2           2               2        2        2        2
# 4          2           2               2        2        2        2
#
#    bilirubin  alk_phosphate  sgot  albumin  protime  histology
# 0        1.0             85    18      4.0       61          1
# ...

# %%
X = data.drop(columns='class', axis=1)
y = data['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('Accuracy of training data :', training_accuracy)
# Out:
# Accuracy of training data : 0.8842105263157894

# %%
X_test_prediction = model.predict(X_test)
test_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print('Accuracy of test data :', test_accuracy)
# Out:
# Accuracy of test data : 0.851063829787234

# %%
input_data =(59,1,1,2,1,1,2,2,1,1,1,2,2,1.5,107,157,3.6,38,2)

# change the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy as we are predicting for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

#if (prediction[1]==1):
 #   print('Survive')
#else:
 #   print('Dies')
    
death = model.predict_proba(input_data_reshaped)[0][0]
life = model.predict_proba(input_data_reshaped)[0][1]

life1=life*100
life2= round(life1, 2)

death1=death*100
death2=round(death1, 2)

print('The patient is',life2,'% probabilty to live\nThe patient is',death2,'% probability to die')
# Out:
# [1]
# The patient is 20.19 % probabilty to live
# The patient is 79.81 % probability to die
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename = 'hepatitis_model.sav'
pickle.dump(model, open(filename, 'wb'))
